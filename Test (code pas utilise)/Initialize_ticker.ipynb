# %%
from download_function import add_ticker_to_json,dowload_all_data

# %%
ticker = "CL=F"
start="2018-06-16"
end="2023-09-15"

# %%
add_ticker_to_json(ticker,start,end)
# Out:
# ⚠️ Le ticker CL=F existe déjà. Mise à jour des dates.
# ✅ Ticker CL=F ajouté ou mis à jour avec succès dans ticker_info.json

# %%
df=dowload_all_data()
# Out:
# Téléchargement de CL=F de 2018-06-16 à 2023-09-15...
# C:\Users\lulul\Desktop\PFE_Outil-de-prevision-du-prix-d-une-matiere-premiere\download_function.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start=start, end=end,interval="1d")
# [*********************100%***********************]  1 of 1 completed

# %%
df[ticker].head(10)
# Out:
# Price           Close       High        Low       Open   Volume
# Ticker           CL=F       CL=F       CL=F       CL=F     CL=F
# Date
# 2018-06-18  65.849998  65.980003  63.590000  64.400002   218933
# 2018-06-19  65.070000  65.900002  64.389999  65.820000   122646
# 2018-06-20  66.220001  66.529999  65.010002  65.110001   801625
# 2018-06-21  65.540001  66.220001  64.339996  65.339996   760719
# 2018-06-22  68.580002  69.379997  65.709999  65.930000  1136232
# 2018-06-25  68.080002  69.440002  67.779999  68.750000   816207
# 2018-06-26  70.529999  70.910004  67.720001  68.209999   848537
# 2018-06-27  72.760002  73.059998  70.559998  70.680000   775155
# 2018-06-28  73.449997  74.029999  72.199997  72.269997   717347
# 2018-06-29  74.150002  74.459999  72.930000  73.330002   602399
